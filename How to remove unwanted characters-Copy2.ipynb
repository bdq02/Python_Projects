# %%
#  Assignment 1 Investigate how to remove unwanted characters, e.g. 1.23km to remove the km in a column AND how to convert datatypes from string to int and from int to str
#  Let's say you have a DataFrame with a column containing values like "1.23km" and you want to extract just the numeric part:

import pandas as pd
import re

# Sample DataFrame
df = pd.DataFrame({
    'distance': ['1.23km', '4.56km', '7.89km', '10.5km'],
    'string_numbers': ['123', '456', '789'],
    'integers': [123, 456, 789]
})

# Method 1: Using str.replace() to remove specific characters
df['distance_clean'] = df['distance'].str.replace('km', '')

# Method 2: Using regular expressions for more complex patterns
df['distance_clean_regex'] = df['distance'].str.extract(r'(\d+\.?\d*)') 

# Method 3: Using str.strip() for removing characters at the beginning or end
df['distance_clean_strip'] = df['distance'].str.rstrip('km')

# Converting the cleaned column to numeric
df['distance_numeric'] = pd.to_numeric(df['distance_clean'])

# Converting between data types
# String to int
df['string_to_int'] = df['string_numbers'].astype(int)

# Int to string
df['int_to_string'] = df['integers'].astype(str)

# Display the results
print(df)


# This code gave an error " All arrays must be of the same length"

# %%
#  Assignment 1 Investigate how to remove unwanted characters, e.g. 1.23km to remove the km in a column AND how to convert datatypes from string to int and from int to str
#  Let's say you have a DataFrame with a column containing values like "1.23km" and you want to extract just the numeric part:

import pandas as pd
import redf = pd.DataFrame({
    'distance': ['1.23km', '4.56km', '7.89km', '10.5km'],
    'string_numbers': ['123', '456', '789', '105'],  # Added fourth element to match length
    'integers': [123, 456, 789, 105]  # Added fourth element to match length
})

# Method 1: Using str.replace() to remove specific characters
df['distance_clean'] = df['distance'].str.replace('km', '')

# Method 2: Using regular expressions for more complex patterns
df['distance_clean_regex'] = df['distance'].str.extract(r'(\d+\.?\d*)') 

# Method 3: Using str.strip() for removing characters at the beginning or end
df['distance_clean_strip'] = df['distance'].str.rstrip('km')

# Converting the cleaned column to numeric
df['distance_numeric'] = pd.to_numeric(df['distance_clean'])

# Converting between data types
# String to int
df['string_to_int'] = df['string_numbers'].astype(int)

# Int to string
df['int_to_string'] = df['integers'].astype(str)

# Display the results
print(df)
# Out:
#   distance string_numbers  integers distance_clean distance_clean_regex  \
# 0   1.23km            123       123           1.23                 1.23
# 1   4.56km            456       456           4.56                 4.56
# 2   7.89km            789       789           7.89                 7.89
# 3   10.5km            105       105           10.5                 10.5
#
#   distance_clean_strip  distance_numeric  string_to_int int_to_string
# 0                 1.23              1.23            123           123
# 1                 4.56              4.56            456           456
# 2                 7.89              7.89            789           789
# 3                 10.5             10.50            105           105

# %%
import pandas as pd
import re

# %%
df = pd.DataFrame({
    'distance': ['1.23km', '4.56km', '7.89km', '10.5km'],
    'string_numbers': ['123', '456', '789', '105'],  # Added fourth element to match length
    'integers': [123, 456, 789, 105]  # Added fourth element to match length
})
print(df)
# Out:
#   distance string_numbers  integers
# 0   1.23km            123       123
# 1   4.56km            456       456
# 2   7.89km            789       789
# 3   10.5km            105       105

# %%
# Method 1: Using str.replace() to remove specific characters
df['distance_clean'] = df['distance'].str.replace('km', '')
print(df['distance_clean'])
# Out:
# 0    1.23
# 1    4.56
# 2    7.89
# 3    10.5
# Name: distance_clean, dtype: object

# %%
# Method 2: Using regular expressions for more complex patterns
df['distance_clean_regex'] = df['distance'].str.extract(r'(\d+\.?\d*)') 
print(df['distance_clean_regex'])
# Out:
# 0    1.23
# 1    4.56
# 2    7.89
# 3    10.5
# Name: distance_clean_regex, dtype: object

# %%
# Converting the cleaned column to numeric
df['distance_numeric'] = pd.to_numeric(df['distance_clean'])
print(df['distance_numeric'])
# Out:
# 0     1.23
# 1     4.56
# 2     7.89
# 3    10.50
# Name: distance_numeric, dtype: float64

# %%
# Converting between data types
# String to int
df['string_to_int'] = df['string_numbers'].astype(int)
print(df['string_to_int'] )
# Out:
# 0    123
# 1    456
# 2    789
# 3    105
# Name: string_to_int, dtype: int64

# %%
# Int to string
df['int_to_string'] = df['integers'].astype(str)
print(df['int_to_string'])
# Out:
# 0    123
# 1    456
# 2    789
# 3    105
# Name: int_to_string, dtype: object

# %%
print("Downloading this file")
